# %%
from tensorflow import keras

from tensorflow.keras import models, layers #type:ignore
 
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, root_mean_squared_error

from tqdm import tqdm
import matplotlib.pyplot as plt 
import numpy as np

# %%
# Preparing the dataset and creating the features and target arrays

n_sims = 10000

x = []
y = []

for i in tqdm(range(n_sims), desc='Carregando dados', ascii=True):
    data = np.load(f'../input31/data_{i+1}.npy')
    x.append(data[:, :2])
    y.append(data[0, 2])  # equivalente a data[:, 2:][0][0]

x = np.array(x)
y = np.array(y)

norm = y.max()
# Normalização
# y /= y.max()


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.25)
# Out:
# Carregando dados: 100%|##########| 10000/10000 [01:21<00:00, 122.55it/s]

# %%
# early_stopping = keras.callbacks.EarlyStopping(
#     min_delta=0.0001, # minimium amount of change to count as an improvement
#     patience=5, # how many epochs to wait before stopping
#     restore_best_weights=True,
# )

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',   
    patience=5,          
    verbose=1,          
    factor=0.5,          
    min_lr=0.00001       
)

# learning_rate_schedule = keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=0.01,  # Initial learning rate for training
#     decay_steps=100,            # Number of steps before decaying the learning rate
#     decay_rate=0.5,              # Rate at which the learning rate decreases
# )

# lr_callback = keras.callbacks.LearningRateScheduler(learning_rate_schedule)

# %%
# defining the model

model = models.Sequential()

model.add(layers.Flatten())


model.add(layers.Dense(16, activation='relu'))

model.add(layers.Dense(16, activation='relu'))

model.add(layers.Dense(1))

model.compile(loss=keras.losses.MeanSquaredError(), optimizer='nadam', metrics=keras.metrics.MeanAbsoluteError())


history = model.fit(x_train, y_train, validation_split=.2, epochs=25, batch_size=8, verbose=1, callbacks=[reduce_lr])
# Out:
# Epoch 1/25
# 750/750 [==============================] - 5s 5ms/step - loss: 26.5086 - mean_absolute_error: 1.7690 - val_loss: 1.5580 - val_mean_absolute_error: 1.0803 - lr: 0.0010
# Epoch 2/25
# 750/750 [==============================] - 4s 5ms/step - loss: 1.9150 - mean_absolute_error: 1.1585 - val_loss: 2.0199 - val_mean_absolute_error: 1.1892 - lr: 0.0010
# Epoch 3/25
# 750/750 [==============================] - 4s 5ms/step - loss: 2.0062 - mean_absolute_error: 1.1678 - val_loss: 1.4515 - val_mean_absolute_error: 1.0076 - lr: 0.0010
# Epoch 4/25
# 750/750 [==============================] - 4s 6ms/step - loss: 2.4189 - mean_absolute_error: 1.2575 - val_loss: 1.2054 - val_mean_absolute_error: 0.9450 - lr: 0.0010
# Epoch 5/25
# 750/750 [==============================] - 4s 5ms/step - loss: 2.0266 - mean_absolute_error: 1.1586 - val_loss: 1.3450 - val_mean_absolute_error: 0.9735 - lr: 0.0010
# Epoch 6/25
# 750/750 [==============================] - 3s 5ms/step - loss: 1.7807 - mean_absolute_error: 1.0873 - val_loss: 0.8621 - val_mean_absolute_error: 0.8027 - lr: 0.0010
# Epoch 7/25
# 750/750 [==============================] - 3s 4ms/step - loss: 1.5158 - mean_absolute_error: 1.0006 - val_loss: 0.9057 - val_mean_absolute_error: 0.7821 - lr: 0.0010
# Epoch 8/25
# 750/750 [==============================] - 3s 4ms/step - loss: 1.2570 - mean_absolute_error: 0.9099 - val_loss: 0.5829 - val_mean_absolute_error: 0.6427 - lr: 0.0010
# Epoch 9/25
# 750/750 [==============================] - 3s 4ms/step - loss: 1.1408 - mean_absolute_error: 0.8520 - val_loss: 0.3758 - val_mean_absolute_error: 0.5193 - lr: 0.0010
# Epoch 10/25
# 750/750 [==============================] - 3s 5ms/step - loss: 0.8186 - mean_absolute_error: 0.7347 - val_loss: 0.3320 - val_mean_absolute_error: 0.4813 - lr: 0.0010
# Epoch 11/25
# 750/750 [==============================] - 4s 5ms/step - loss: 0.6158 - mean_absolute_error: 0.6269 - val_loss: 0.1944 - val_mean_absolute_error: 0.3678 - lr: 0.0010
# Epoch 12/25
# 750/750 [==============================] - 4s 5ms/step - loss: 0.5515 - mean_absolute_error: 0.5951 - val_loss: 0.1089 - val_mean_absolute_error: 0.2794 - lr: 0.0010
# Epoch 13/25
# 750/750 [==============================] - 4s 5ms/step - loss: 0.4034 - mean_absolute_error: 0.4934 - val_loss: 0.1914 - val_mean_absolute_error: 0.3756 - lr: 0.0010
# Epoch 14/25
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3593 - mean_absolute_error: 0.4767 - val_loss: 0.0726 - val_mean_absolute_error: 0.2239 - lr: 0.0010
# Epoch 15/25
# 750/750 [==============================] - 4s 5ms/step - loss: 0.3069 - mean_absolute_error: 0.4428 - val_loss: 0.1345 - val_mean_absolute_error: 0.3097 - lr: 0.0010
# Epoch 16/25
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2710 - mean_absolute_error: 0.4128 - val_loss: 0.1573 - val_mean_absolute_error: 0.3591 - lr: 0.0010
# Epoch 17/25
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2487 - mean_absolute_error: 0.3842 - val_loss: 0.0769 - val_mean_absolute_error: 0.2515 - lr: 0.0010
# Epoch 18/25
# 750/750 [==============================] - 4s 5ms/step - loss: 0.2633 - mean_absolute_error: 0.3951 - val_loss: 0.1147 - val_mean_absolute_error: 0.2856 - lr: 0.0010
# Epoch 19/25
# 745/750 [============================>.] - ETA: 0s - loss: 0.1693 - mean_absolute_error: 0.3295
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 750/750 [==============================] - 4s 5ms/step - loss: 0.1692 - mean_absolute_error: 0.3297 - val_loss: 0.2592 - val_mean_absolute_error: 0.4709 - lr: 0.0010
# Epoch 20/25
# 750/750 [==============================] - 4s 6ms/step - loss: 0.0326 - mean_absolute_error: 0.1490 - val_loss: 0.0165 - val_mean_absolute_error: 0.1084 - lr: 5.0000e-04
# Epoch 21/25
# 750/750 [==============================] - 4s 5ms/step - loss: 0.0214 - mean_absolute_error: 0.1182 - val_loss: 0.0060 - val_mean_absolute_error: 0.0635 - lr: 5.0000e-04
# Epoch 22/25
# 750/750 [==============================] - 4s 5ms/step - loss: 0.0383 - mean_absolute_error: 0.1549 - val_loss: 0.0530 - val_mean_absolute_error: 0.2252 - lr: 5.0000e-04
# Epoch 23/25
# 750/750 [==============================] - 4s 5ms/step - loss: 0.0363 - mean_absolute_error: 0.1532 - val_loss: 0.0030 - val_mean_absolute_error: 0.0457 - lr: 5.0000e-04
# Epoch 24/25
# 750/750 [==============================] - 4s 5ms/step - loss: 0.0355 - mean_absolute_error: 0.1485 - val_loss: 0.0054 - val_mean_absolute_error: 0.0631 - lr: 5.0000e-04
# Epoch 25/25
# 750/750 [==============================] - 4s 5ms/step - loss: 0.0324 - mean_absolute_error: 0.1349 - val_loss: 0.0636 - val_mean_absolute_error: 0.2508 - lr: 5.0000e-04

# %%
plt.plot(history.history['val_loss'][1:], label='Validação')
plt.plot(history.history['loss'][1:], label='Treino')


plt.xlabel('Épocas')
plt.legend()


# plt.savefig("imagens/loss_h0_dense")

plt.show()

# %%
y_pred = model.predict(x_test)


r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)

mse
# Out:
# 79/79 [==============================] - 0s 1ms/step
# 0.06309415253105187

# %%
plt.style.use('seaborn-v0_8-muted')

linha = np.linspace(64, 81)
# linha = np.linspace(.28, .35, 2500)


# plt.scatter(y_pred*norm, y_test*norm, s=5, alpha=.6, label=f'R2 = {r2:.4f}')
plt.scatter(y_pred, y_test, s=5, alpha=.6, label=f'R2 = {r2:.4f}')
plt.plot(linha, linha, alpha=.5, c='red', ls='--')

plt.legend()


plt.xlabel(r'$H (z)$ previsto [$km s^{-1} Mpc^{-1}$] ')
plt.ylabel(r'$H (z)$ de teste [$km s^{-1} Mpc^{-1}$] ')


# plt.savefig("imagens/metrics_h0_dense")
plt.show()

# %%
# forecasting "real" H(0)

real = np.load('../input31/data_real31.npy')
# real = real[real[:, 1].argsort()]

real = real.reshape(-1,31,2)

# %%
plt.scatter(real[:, :, 0][0], real[:, :, 1][0], s=8)
plt.plot(real[:, :, 0][0], real[:, :, 1][0], alpha=.6)

plt.xlabel(r'$z$')
plt.ylabel(r'$H (z)$[$km s^{-1} Mpc^{-1}$] ')

plt.show()

# %%
final_real = model.predict(real, verbose=0)

# %%
# final_real*norm
final_real
# Out:
# array([[57.46222]], dtype=float32)

# %%
# keras.utils.plot_model(model, to_file='imagens/model_dense.png', show_shapes=False, show_layer_names=False)

# %%
# model.save('models/dense')
