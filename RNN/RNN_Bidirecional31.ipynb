# %%
from tensorflow import keras

from tensorflow.keras import models, layers  # type: ignore

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, root_mean_squared_error

from tqdm import tqdm
import matplotlib.pyplot as plt 
import numpy as np

# %%
# h0 = 67,45
# omega_m = 0.315

# %%
# Preparing the dataset and creating the features and target arrays

n_sims = 1000

x = []
y = []

for i in tqdm(range(n_sims), desc='Carregando dados', ascii=True):
    data = np.load(f'../input31/data_{i+1}.npy')
    x.append(data[:, :2])
    y.append(data[0, 2])  # equivalente a data[:, 2:][0][0]

x = np.array(x)
y = np.array(y)

norm = y.max()
# Normalização
# y /= y.max()


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.25)
# Out:
# Carregando dados: 100%|##########| 1000/1000 [00:00<00:00, 5153.39it/s]

# %%
# early_stopping = keras.callbacks.EarlyStopping(
#     min_delta=0.001, # minimium amount of change to count as an improvement
#     patience=5, # how many epochs to wait before stopping
#     restore_best_weights=True,
# )

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',   
    patience=5,          
    verbose=1,          
    factor=0.5,          
    min_lr=0.00001       
)

learning_rate_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,  # Initial learning rate for training
    decay_steps=5,            # Number of steps before decaying the learning rate
    decay_rate=0.5,              # Rate at which the learning rate decreases
)

lr_callback = keras.callbacks.LearningRateScheduler(learning_rate_schedule)

# %%
# defining the model


model = models.Sequential()

# model.add()

model.add(layers.Bidirectional(layers.GRU(16,input_shape=(31,2)) ) )


model.add(layers.Flatten())

model.add(layers.Dense(16))
# model.add(layers.Dropout(.3))

model.add(layers.Dense(1))

model.compile(loss=keras.losses.MeanSquaredError(), optimizer='nadam', metrics=keras.metrics.MeanAbsoluteError())


history = model.fit(x_train, y_train, validation_split=.1, epochs=20, batch_size=8, verbose=1, callbacks=[reduce_lr])
# Out:
# Epoch 1/20
# 85/85 [==============================] - 4s 18ms/step - loss: 4059.5879 - mean_absolute_error: 63.3641 - val_loss: 2856.4392 - val_mean_absolute_error: 53.2766 - lr: 0.0010
# Epoch 2/20
# 85/85 [==============================] - 1s 13ms/step - loss: 1764.1598 - mean_absolute_error: 41.2454 - val_loss: 891.6834 - val_mean_absolute_error: 29.5643 - lr: 0.0010
# Epoch 3/20
# 85/85 [==============================] - 1s 13ms/step - loss: 404.8852 - mean_absolute_error: 18.8647 - val_loss: 121.1650 - val_mean_absolute_error: 10.1606 - lr: 0.0010
# Epoch 4/20
# 85/85 [==============================] - 1s 13ms/step - loss: 46.5827 - mean_absolute_error: 5.5965 - val_loss: 21.9088 - val_mean_absolute_error: 3.8521 - lr: 0.0010
# Epoch 5/20
# 85/85 [==============================] - 1s 13ms/step - loss: 19.3843 - mean_absolute_error: 3.7789 - val_loss: 18.0049 - val_mean_absolute_error: 3.4658 - lr: 0.0010
# Epoch 6/20
# 85/85 [==============================] - 1s 13ms/step - loss: 18.8037 - mean_absolute_error: 3.7376 - val_loss: 17.8772 - val_mean_absolute_error: 3.4598 - lr: 0.0010
# Epoch 7/20
# 85/85 [==============================] - 1s 13ms/step - loss: 18.7928 - mean_absolute_error: 3.7366 - val_loss: 17.8492 - val_mean_absolute_error: 3.4457 - lr: 0.0010
# Epoch 8/20
# 85/85 [==============================] - 1s 13ms/step - loss: 17.6396 - mean_absolute_error: 3.6047 - val_loss: 14.5715 - val_mean_absolute_error: 3.1069 - lr: 0.0010
# Epoch 9/20
# 85/85 [==============================] - 1s 13ms/step - loss: 13.9123 - mean_absolute_error: 3.1915 - val_loss: 12.4321 - val_mean_absolute_error: 2.9003 - lr: 0.0010
# Epoch 10/20
# 85/85 [==============================] - 1s 14ms/step - loss: 11.5172 - mean_absolute_error: 2.9112 - val_loss: 9.6498 - val_mean_absolute_error: 2.5591 - lr: 0.0010
# Epoch 11/20
# 85/85 [==============================] - 1s 14ms/step - loss: 7.8281 - mean_absolute_error: 2.3557 - val_loss: 6.3333 - val_mean_absolute_error: 2.1758 - lr: 0.0010
# Epoch 12/20
# 85/85 [==============================] - 1s 13ms/step - loss: 3.9619 - mean_absolute_error: 1.6645 - val_loss: 2.2060 - val_mean_absolute_error: 1.2223 - lr: 0.0010
# Epoch 13/20
# 85/85 [==============================] - 1s 14ms/step - loss: 1.7460 - mean_absolute_error: 1.0585 - val_loss: 3.0382 - val_mean_absolute_error: 1.6073 - lr: 0.0010
# Epoch 14/20
# 85/85 [==============================] - 1s 13ms/step - loss: 1.1719 - mean_absolute_error: 0.8496 - val_loss: 0.5904 - val_mean_absolute_error: 0.5915 - lr: 0.0010
# Epoch 15/20
# 85/85 [==============================] - 1s 13ms/step - loss: 0.6838 - mean_absolute_error: 0.6649 - val_loss: 0.4964 - val_mean_absolute_error: 0.5128 - lr: 0.0010
# Epoch 16/20
# 85/85 [==============================] - 1s 13ms/step - loss: 0.4532 - mean_absolute_error: 0.5343 - val_loss: 1.0068 - val_mean_absolute_error: 0.8865 - lr: 0.0010
# Epoch 17/20
# 85/85 [==============================] - 1s 14ms/step - loss: 0.5842 - mean_absolute_error: 0.6109 - val_loss: 0.3518 - val_mean_absolute_error: 0.4728 - lr: 0.0010
# Epoch 18/20
# 85/85 [==============================] - 1s 13ms/step - loss: 0.3899 - mean_absolute_error: 0.5072 - val_loss: 0.5153 - val_mean_absolute_error: 0.6201 - lr: 0.0010
# Epoch 19/20
# 85/85 [==============================] - 1s 13ms/step - loss: 0.3744 - mean_absolute_error: 0.4991 - val_loss: 0.3064 - val_mean_absolute_error: 0.4148 - lr: 0.0010
# Epoch 20/20
# 85/85 [==============================] - 1s 13ms/step - loss: 0.3451 - mean_absolute_error: 0.4651 - val_loss: 0.6379 - val_mean_absolute_error: 0.6911 - lr: 0.0010

# %%
plt.plot(history.history['val_loss'][1:], label='Validação')
plt.plot(history.history['loss'][1:], label='Treino')


plt.xlabel('Épocas')
plt.legend()


# plt.savefig("../imagens/loss_h0_rnn_bi")

plt.show()

# %% [markdown]
# Dummy variables just for visualization purposes

# %%
y_pred = model.predict(x_test)


r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)

# mse
# Out:
# 8/8 [==============================] - 1s 4ms/step

# %%
plt.style.use('seaborn-v0_8-muted')

# linha = np.linspace(.3, .35, 2500)
linha = np.linspace(65, 80)

plt.scatter(y_pred, y_test, s=5, alpha=.6, label=f'R2 = {r2:.4f}')
plt.plot(linha, linha, alpha=.5, c='red', ls='--')

plt.legend()


plt.xlabel(r'$H (z)$ previsto [$km s^{-1} Mpc^{-1}$] ')
plt.ylabel(r'$H (z)$ de teste [$km s^{-1} Mpc^{-1}$] ')


# plt.savefig("../imagens/metrics_h0_rnn_bi")
plt.show()

# %%
# forecasting "real" H(0)

real = np.load('../input31/data_real31.npy')
# real = real[real[:, 1].argsort()]

real = real.reshape(-1,31,2)

# %%
final_real = model.predict(real, verbose=0)

# %%
final_real
# Out:
# array([[65.0636]], dtype=float32)

# %%
# keras.utils.plot_model(model, to_file='../imagens/model_rnn_bi.png', show_shapes=False, show_layer_names=False)

# %%
# model.save('../models/rnn_bi')
