# %%
from tensorflow import keras

from tensorflow.keras import models, layers #type:ignore

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, root_mean_squared_error

from tqdm import tqdm
import matplotlib.pyplot as plt 
import numpy as np

# %%
# h0 = 67,45
# omega_m = 0.315

# %%
# Preparing the dataset and creating the features and target arrays

n_sims = 10000

x = []
y = []

for i in tqdm(range(n_sims), desc='Carregando dados', ascii=True):
    data = np.load(f'../input/data_{i+1}.npy')
    x.append(data[:, :2])
    y.append(data[0, 2])  # equivalente a data[:, 2:][0][0]

x = np.array(x)
y = np.array(y)

norm = y.max()
# Normalização
y /= y.max()


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.25)
# Out:
# Carregando dados: 100%|##########| 10000/10000 [01:19<00:00, 126.20it/s]

# %%
# early_stopping = keras.callbacks.EarlyStopping(
#     min_delta=0.001, # minimium amount of change to count as an improvement
#     patience=5, # how many epochs to wait before stopping
#     restore_best_weights=True,
# )

# reduce_lr = keras.callbacks.ReduceLROnPlateau(
#     monitor='val_loss',   
#     patience=5,          
#     verbose=1,          
#     factor=0.5,          
#     min_lr=0.00001       
# )

learning_rate_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,  # Initial learning rate for training
    decay_steps=5,            # Number of steps before decaying the learning rate
    decay_rate=0.5,              # Rate at which the learning rate decreases
)

lr_callback = keras.callbacks.LearningRateScheduler(learning_rate_schedule)

# %%
# defining the model


model = models.Sequential()

model.add(layers.GRU(32,input_shape=(80,2)))

model.add(layers.Flatten())

model.add(layers.Dense(16))
# model.add(layers.Dropout(.3))

model.add(layers.Dense(1))

model.compile(loss=keras.losses.MeanSquaredError(), optimizer='nadam', metrics=keras.metrics.MeanAbsoluteError())


history = model.fit(x_train, y_train, validation_split=.1, epochs=20, batch_size=16, verbose=1, callbacks=[lr_callback])
# Out:
# Epoch 1/20
# 422/422 [==============================] - 8s 12ms/step - loss: 0.0144 - mean_absolute_error: 0.0818 - val_loss: 0.0025 - val_mean_absolute_error: 0.0435 - lr: 0.0100
# Epoch 2/20
# 422/422 [==============================] - 5s 13ms/step - loss: 0.0048 - mean_absolute_error: 0.0477 - val_loss: 0.0052 - val_mean_absolute_error: 0.0715 - lr: 0.0087
# Epoch 3/20
# 422/422 [==============================] - 4s 11ms/step - loss: 0.0013 - mean_absolute_error: 0.0280 - val_loss: 1.7811e-04 - val_mean_absolute_error: 0.0118 - lr: 0.0076
# Epoch 4/20
# 422/422 [==============================] - 4s 10ms/step - loss: 6.2949e-04 - mean_absolute_error: 0.0189 - val_loss: 6.4788e-04 - val_mean_absolute_error: 0.0235 - lr: 0.0066
# Epoch 5/20
# 422/422 [==============================] - 4s 11ms/step - loss: 2.4183e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0011 - val_mean_absolute_error: 0.0326 - lr: 0.0057
# Epoch 6/20
# 422/422 [==============================] - 6s 14ms/step - loss: 1.4677e-04 - mean_absolute_error: 0.0091 - val_loss: 2.6881e-04 - val_mean_absolute_error: 0.0154 - lr: 0.0050
# Epoch 7/20
# 422/422 [==============================] - 7s 16ms/step - loss: 9.1257e-05 - mean_absolute_error: 0.0076 - val_loss: 2.4600e-04 - val_mean_absolute_error: 0.0149 - lr: 0.0044
# Epoch 8/20
# 422/422 [==============================] - 7s 17ms/step - loss: 6.2396e-05 - mean_absolute_error: 0.0063 - val_loss: 3.7117e-04 - val_mean_absolute_error: 0.0187 - lr: 0.0038
# Epoch 9/20
# 422/422 [==============================] - 7s 17ms/step - loss: 7.6835e-05 - mean_absolute_error: 0.0070 - val_loss: 8.9733e-05 - val_mean_absolute_error: 0.0084 - lr: 0.0033
# Epoch 10/20
# 422/422 [==============================] - 7s 16ms/step - loss: 5.5487e-05 - mean_absolute_error: 0.0059 - val_loss: 1.9198e-05 - val_mean_absolute_error: 0.0037 - lr: 0.0029
# Epoch 11/20
# 422/422 [==============================] - 8s 19ms/step - loss: 3.8807e-05 - mean_absolute_error: 0.0050 - val_loss: 1.9851e-04 - val_mean_absolute_error: 0.0134 - lr: 0.0025
# Epoch 12/20
# 422/422 [==============================] - 8s 20ms/step - loss: 4.2756e-05 - mean_absolute_error: 0.0053 - val_loss: 3.2373e-05 - val_mean_absolute_error: 0.0046 - lr: 0.0022
# Epoch 13/20
# 422/422 [==============================] - 11s 25ms/step - loss: 3.2066e-05 - mean_absolute_error: 0.0045 - val_loss: 1.1106e-04 - val_mean_absolute_error: 0.0096 - lr: 0.0019
# Epoch 14/20
# 422/422 [==============================] - 11s 26ms/step - loss: 3.4251e-05 - mean_absolute_error: 0.0048 - val_loss: 5.0139e-05 - val_mean_absolute_error: 0.0059 - lr: 0.0016
# Epoch 15/20
# 422/422 [==============================] - 9s 22ms/step - loss: 2.4850e-05 - mean_absolute_error: 0.0041 - val_loss: 1.7635e-05 - val_mean_absolute_error: 0.0036 - lr: 0.0014
# Epoch 16/20
# 422/422 [==============================] - 9s 20ms/step - loss: 2.6740e-05 - mean_absolute_error: 0.0042 - val_loss: 2.8954e-05 - val_mean_absolute_error: 0.0045 - lr: 0.0012
# Epoch 17/20
# 422/422 [==============================] - 8s 19ms/step - loss: 2.7403e-05 - mean_absolute_error: 0.0043 - val_loss: 4.5690e-05 - val_mean_absolute_error: 0.0056 - lr: 0.0011
# Epoch 18/20
# 422/422 [==============================] - 8s 19ms/step - loss: 2.3939e-05 - mean_absolute_error: 0.0040 - val_loss: 2.1725e-05 - val_mean_absolute_error: 0.0039 - lr: 9.4732e-04
# Epoch 19/20
# 422/422 [==============================] - 8s 19ms/step - loss: 2.1785e-05 - mean_absolute_error: 0.0039 - val_loss: 1.7817e-05 - val_mean_absolute_error: 0.0035 - lr: 8.2469e-04
# Epoch 20/20
# 422/422 [==============================] - 8s 19ms/step - loss: 2.1720e-05 - mean_absolute_error: 0.0039 - val_loss: 2.7012e-05 - val_mean_absolute_error: 0.0043 - lr: 7.1794e-04

# %%
plt.plot(history.history['val_loss'][1:], label='Validação')
plt.plot(history.history['loss'][1:], label='Treino')


plt.xlabel('Épocas')
plt.legend()


plt.savefig("../imagens/loss_h0_rnn")

plt.show()

# %% [markdown]
# Dummy variables just for visualization purposes

# %%
y_pred = model.predict(x_test)


r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)

# mse
# Out:
# 79/79 [==============================] - 1s 5ms/step

# %%
plt.style.use('seaborn-v0_8-muted')

# linha = np.linspace(.3, .35, 2500)
linha = np.linspace(65, 80)

plt.scatter(y_pred*norm, y_test*norm, s=5, alpha=.6, label=f'R2 = {r2:.4f}')
plt.plot(linha, linha, alpha=.5, c='red', ls='--')

plt.legend()


plt.xlabel(r'$H (z)$ previsto [$km s^{-1} Mpc^{-1}$] ')
plt.ylabel(r'$H (z)$ de teste [$km s^{-1} Mpc^{-1}$] ')


plt.savefig("../imagens/metrics_h0_rnn")
plt.show()

# %%
# forecasting "real" H(0)

real = np.load('../input/data_real80.npy')
real = real[real[:, 1].argsort()]

real = real.reshape(-1,80,2)

# %%
final_real = model.predict(real, verbose=0)

# %%
final_real*norm
# Out:
# array([[67.659935]], dtype=float32)

# %%
keras.utils.plot_model(model, to_file='../imagens/model_rnn.png', show_shapes=False, show_layer_names=False)

# %%
model.save('../models/rnn')
# Out:
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ../models/rnn\assets
# INFO:tensorflow:Assets written to: ../models/rnn\assets
