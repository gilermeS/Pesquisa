# %%
from tensorflow import keras

from tensorflow.keras import models, layers  # type: ignore

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error, root_mean_squared_error

from tqdm import tqdm
import matplotlib.pyplot as plt 
import numpy as np

# %%
# h0 = 67,45
# omega_m = 0.315

# %%
# Preparing the dataset and creating the features and target arrays

n_sims = 10000

x = []
y = []

for i in tqdm(range(n_sims), desc='Carregando dados', ascii=True):
    data = np.load(f'../input47/data_{i+1}.npy')
    x.append(data[:, :2])
    y.append(data[0, 2])  # equivalente a data[:, 2:][0][0]

x = np.array(x)
y = np.array(y)

norm = y.max()
# Normalização
# y /= y.max()


x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=.25)
# Out:
# Carregando dados: 100%|##########| 10000/10000 [00:01<00:00, 6115.93it/s]

# %%
# early_stopping = keras.callbacks.EarlyStopping(
#     min_delta=0.001, # minimium amount of change to count as an improvement
#     patience=5, # how many epochs to wait before stopping
#     restore_best_weights=True,
# )

reduce_lr = keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss',   
    patience=5,          
    verbose=1,          
    factor=0.5,          
    min_lr=0.00001,
    min_delta=0.001       
)

# learning_rate_schedule = keras.optimizers.schedules.ExponentialDecay(
#     initial_learning_rate=0.01,  # Initial learning rate for training
#     decay_steps=5,            # Number of steps before decaying the learning rate
#     decay_rate=0.5,              # Rate at which the learning rate decreases
# )

# lr_callback = keras.callbacks.LearningRateScheduler(learning_rate_schedule)

# %%
# defining the model


model = models.Sequential()

# model.add()

model.add(layers.Bidirectional(layers.GRU(16,input_shape=(47,2)) ) )


model.add(layers.Flatten())

model.add(layers.Dense(16))
# model.add(layers.Dropout(.3))

model.add(layers.Dense(1))

model.compile(loss=keras.losses.MeanSquaredError(), optimizer='nadam', metrics=keras.metrics.MeanAbsoluteError())


history = model.fit(x_train, y_train, validation_split=.1, epochs=20, batch_size=8, verbose=1, callbacks=[reduce_lr])
# Out:
# Epoch 1/20
# 844/844 [==============================] - 16s 14ms/step - loss: 661.1177 - mean_absolute_error: 15.3251 - val_loss: 19.0906 - val_mean_absolute_error: 3.8139 - lr: 0.0010
# Epoch 2/20
# 844/844 [==============================] - 12s 14ms/step - loss: 12.4443 - mean_absolute_error: 2.8864 - val_loss: 0.9699 - val_mean_absolute_error: 0.7455 - lr: 0.0010
# Epoch 3/20
# 844/844 [==============================] - 17s 20ms/step - loss: 0.6499 - mean_absolute_error: 0.6324 - val_loss: 0.1990 - val_mean_absolute_error: 0.3652 - lr: 0.0010
# Epoch 4/20
# 844/844 [==============================] - 22s 27ms/step - loss: 0.2460 - mean_absolute_error: 0.3889 - val_loss: 0.2754 - val_mean_absolute_error: 0.4650 - lr: 0.0010
# Epoch 5/20
# 844/844 [==============================] - 20s 24ms/step - loss: 0.1884 - mean_absolute_error: 0.3416 - val_loss: 0.0531 - val_mean_absolute_error: 0.1932 - lr: 0.0010
# Epoch 6/20
# 844/844 [==============================] - 20s 23ms/step - loss: 0.1699 - mean_absolute_error: 0.3169 - val_loss: 0.3565 - val_mean_absolute_error: 0.5482 - lr: 0.0010
# Epoch 7/20
# 844/844 [==============================] - 22s 26ms/step - loss: 0.1495 - mean_absolute_error: 0.3021 - val_loss: 0.0690 - val_mean_absolute_error: 0.2118 - lr: 0.0010
# Epoch 8/20
# 844/844 [==============================] - 22s 26ms/step - loss: 0.1427 - mean_absolute_error: 0.3011 - val_loss: 0.1453 - val_mean_absolute_error: 0.3227 - lr: 0.0010
# Epoch 9/20
# 844/844 [==============================] - 22s 26ms/step - loss: 0.1215 - mean_absolute_error: 0.2784 - val_loss: 0.1153 - val_mean_absolute_error: 0.2877 - lr: 0.0010
# Epoch 10/20
# 844/844 [==============================] - ETA: 0s - loss: 0.1226 - mean_absolute_error: 0.2780
# Epoch 10: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 844/844 [==============================] - 27s 32ms/step - loss: 0.1226 - mean_absolute_error: 0.2780 - val_loss: 0.2392 - val_mean_absolute_error: 0.4470 - lr: 0.0010
# Epoch 11/20
# 844/844 [==============================] - 25s 30ms/step - loss: 0.0408 - mean_absolute_error: 0.1664 - val_loss: 0.0455 - val_mean_absolute_error: 0.1717 - lr: 5.0000e-04
# Epoch 12/20
# 844/844 [==============================] - 18s 21ms/step - loss: 0.0432 - mean_absolute_error: 0.1695 - val_loss: 0.0451 - val_mean_absolute_error: 0.1727 - lr: 5.0000e-04
# Epoch 13/20
# 844/844 [==============================] - 18s 21ms/step - loss: 0.0475 - mean_absolute_error: 0.1757 - val_loss: 0.0398 - val_mean_absolute_error: 0.1599 - lr: 5.0000e-04
# Epoch 14/20
# 844/844 [==============================] - 23s 28ms/step - loss: 0.0445 - mean_absolute_error: 0.1698 - val_loss: 0.0757 - val_mean_absolute_error: 0.2238 - lr: 5.0000e-04
# Epoch 15/20
# 844/844 [==============================] - 24s 28ms/step - loss: 0.0419 - mean_absolute_error: 0.1640 - val_loss: 0.0757 - val_mean_absolute_error: 0.2433 - lr: 5.0000e-04
# Epoch 16/20
# 844/844 [==============================] - 21s 25ms/step - loss: 0.0374 - mean_absolute_error: 0.1538 - val_loss: 0.0203 - val_mean_absolute_error: 0.1178 - lr: 5.0000e-04
# Epoch 17/20
# 844/844 [==============================] - 25s 29ms/step - loss: 0.0341 - mean_absolute_error: 0.1474 - val_loss: 0.0489 - val_mean_absolute_error: 0.1851 - lr: 5.0000e-04
# Epoch 18/20
# 844/844 [==============================] - 23s 27ms/step - loss: 0.0325 - mean_absolute_error: 0.1430 - val_loss: 0.0165 - val_mean_absolute_error: 0.1058 - lr: 5.0000e-04
# Epoch 19/20
# 844/844 [==============================] - 23s 27ms/step - loss: 0.0291 - mean_absolute_error: 0.1346 - val_loss: 0.0812 - val_mean_absolute_error: 0.2646 - lr: 5.0000e-04
# Epoch 20/20
# 844/844 [==============================] - 20s 24ms/step - loss: 0.0277 - mean_absolute_error: 0.1312 - val_loss: 0.0362 - val_mean_absolute_error: 0.1641 - lr: 5.0000e-04

# %%
plt.plot(history.history['val_loss'][1:], label='Validação')
plt.plot(history.history['loss'][1:], label='Treino')


plt.xlabel('Épocas')
plt.legend()


# plt.savefig("../imagens/loss_h0_rnn_bi")

plt.show()

# %% [markdown]
# Dummy variables just for visualization purposes

# %%
y_pred = model.predict(x_test)


r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred)

# mse
# Out:
# 79/79 [==============================] - 3s 13ms/step

# %%
plt.style.use('seaborn-v0_8-muted')

# linha = np.linspace(.3, .35, 2500)
linha = np.linspace(65, 80)

plt.scatter(y_pred, y_test, s=5, alpha=.6, label=f'R2 = {r2:.4f}')
plt.plot(linha, linha, alpha=.5, c='red', ls='--')

plt.legend()


plt.xlabel(r'$H (z)$ previsto [$km s^{-1} Mpc^{-1}$] ')
plt.ylabel(r'$H (z)$ de teste [$km s^{-1} Mpc^{-1}$] ')


# plt.savefig("../imagens/metrics_h0_rnn_bi")
plt.show()

# %%
# forecasting "real" H(0)

real = np.load('../input47/data_real47.npy')
# real = real[real[:, 1].argsort()]

real = real.reshape(-1,47,2)

# %%
final_real = model.predict(real, verbose=0)

# %%
final_real
# Out:
# array([[63.79551]], dtype=float32)

# %%
# keras.utils.plot_model(model, to_file='../imagens/model_rnn_bi.png', show_shapes=False, show_layer_names=False)

# %%
# model.save('../models/rnn_bi')
